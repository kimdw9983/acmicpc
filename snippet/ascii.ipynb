# %%
i = 97
c = 'a'

# %% [markdown]
# ## int -> char

# %%
chr(i)
# Out:
# 'a'

# %% [markdown]
# ## char -> int

# %%
ord(c)
# Out:
# 97

# %% [markdown]
# ## 0부터 9
# - ![image.png](attachment:image.png)

# %%
c = '5'
ord(c) - 48
# Out:
# 5

# %% [markdown]
# ## 대소문자
# - ![image.png](attachment:image.png)

# %% [markdown]
# - 소문자

# %%
c = 'g'
ord(c) - 97
# Out:
# 0

# %% [markdown]
# - 대문자

# %%
c = 'U'
ord(c) - 65
# Out:
# 20

# %% [markdown]
# # 대소문자 변환
# - 32만큼 차이가 난다.

# %%
c = 'A'
print(chr(ord(c) + 32))
c = 'z'
print(chr(ord(c) - 32))
# Out:
# a
# Z
