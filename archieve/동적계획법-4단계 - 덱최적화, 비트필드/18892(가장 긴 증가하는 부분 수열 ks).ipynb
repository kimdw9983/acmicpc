# %% [markdown]
# 6 1
# 10 20 10 30 20 50
# 5 1
# 3 5 2 6 1
# 5 1
# 1 4 2 3 5
# 5 2
# 1 4 2 3 5
# 6 1
# 2 6 4 1 3 5
# 6 2
# 2 6 4 1 3 5
# 6 3
# 2 6 4 1 3 5
# 6 4
# 2 6 4 1 3 5
# 6 6
# 1 1 2 3 2 3

# %% [markdown]
# - 시간복잡도 문제로 풀지 못했다.
# ### 최단거리 index의 의미 해석(18892) - 잘못된 해석
# - index 리스트를 거꾸로 보면서 LIS 길이에서 1씩 줄여가며 첫번째로 보이는 index가 가리키는 원소를 출력했다.
# - 이렇게 거꾸로가는 iteration 중에 감소하는 순서로 index를 선택하기만 한다면 모든 LIS를 출력할 수 있을 것으로 보인다.
# - `DP[x][y]` = index리스트를 거꾸로 보면서, x보다 앞에 있으면서 LIS를 구성할 수 있는, 뒤에서 y번째 숫자인 인덱스들

# %%
import bisect
N, K = map(int, input().split())
DATA = [*map(int, input().split())]
l = [0] * N
LIS = [-float("inf")]
MAX = 0 

for i, n in enumerate(DATA) : 
  if LIS[-1] < n: 
    LIS.append(n)
    l[i] = len(LIS) - 1
    MAX = l[i]
  else:
    l[i] = bisect.bisect_left(LIS, n)
    LIS[l[i]] = n

result = []
def r(i, n, ll) : #i부터 거꾸로 보면서 n을 찾는다.
  # print(i, n, ll)
  if i < 0 : return
  for j in range(i, -1, -1):
    if l[j] != n : continue #찾아야 하는 수
    if DATA[ll[-1]] <= DATA[j] : continue #증가하는 수열이면 안됨
    if n == 1 :
      x = ll+[j]
      lll = []
      for k in x[::-1] :
        lll.append(DATA[k]) #우선순위큐
      result.append(lll)
    r(j-1, n-1, ll+[j])

#재귀
for i in range(len(l)-1, 0, -1) :
  v = l[i]
  if v == MAX :
    r(i-1, v-1, [i])
  
result.sort()
if K > len(result) :
  print(-1)
else :
  print(*result[K-1])

# %% [markdown]
# - TLE, 재귀 함수가 시간복잡도 지수적으로 증가.
# - [2, 1, 4, 3, 6, 5, ...] 의 입력은 2^(n/2)개 만큼의 LIS가 있다. 따라서 이러한 접근으로는 풀 수 없다.
#   - 특히 n이 500인 경우 2^250개가 되므로, 이를 모두 풀기엔 메모리도 부족하게 된다.
#
# ### 풀이
# - LIS의 개수를 구하는 함수를 만들고, LIS를 재구성 한다 O(N^2 log N)

# %%
import collections
N, K = map(int, input().split())
L = [*map(int, input().split())]

M = [-1] * (N + 1) #메모
def LIS(s) : #L[s]에서 시작하는 IS중 최대 길이를 반환한다.
  ret = M[s + 1]
  if ret != -1 : return ret #항상 S[s]는 있기 때문에 길이는 최소 1이다.

  ret = 1
  for i in range(s + 1, N) :
    if s == -1 or L[s] < L[i] :
      ret = max(ret, LIS(i) + 1)
  return ret
    
def count(s): #S[s]에서 시작하는 LIS의 갯수를 반환한다.
  if LIS(s) == 1: return 1 #L[s]에서 시작하는 LIS가 1이면 자기 자신만 있다.
  ret = M[s + 1]
  if ret != -1 : return ret #메모이제이션

  ret = 0
  for i in range(s + 1, N) :
    if (s == -1 or L[s] < L[i]) and LIS(s) == LIS(i) + 1 :
      ret = min(2000000000, ret + count(i))
  return ret

def reconstruct(s, skip, lis: collections.deque) :
  if s != -1 : lis.appendleft(L[s]) #
  followers = collections.deque()
  for i in range(s + 1, N) :
    if (s == -1 or L[s] < L[i]) and LIS(s) == LIS(i) + 1 :
      followers.appendleft((L[i], i))
  followers = sorted(followers)

  for i in range(len(followers)) :
    idx = followers[i][1]
    cnt = count(idx)
    if cnt <= skip :
      skip -= cnt
    else :
      reconstruct(idx, skip, lis)
      break

x = collections.deque()
reconstruct(-1, K - 1, x)
if x :
  print(" ".join(map(str, reversed(x))))
else :
  print(-1)

# %% [markdown]
# - 아무래도 이것도 TLE가 나는 것 같다.

# %% [markdown]
# ### 아이디어
# - 우선 LIS가 $2^{250}$ 개나 나올 수 있는 최악 케이스인 `2 1 4 3 6 5 ...` 의 경우 로컬에서조차 풀리지 않았다.
# - LIS()만 돌려도 로컬에서 답이 안나온다. 이를 $O(N \log N)$ 으로 개선해서 총 연산시간을 줄여볼 수 있다.
#   - 여전히 프로그램의 시간복잡도는 $O(N^2 \log N)$ 이겠지만, 개선이 될 수 있다.

# %%
import collections, io, os, bisect
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

MAX = 2e9 + 7777
def sol() :
  N, K = map(int, input().split())
  L = [*map(int, input().split())]

  DP = [-1] * N #L[i]에서 시작하는 LIS의 길이
  for s in range(N) :
    bis = [-MAX]
    for num in L[s:] :
      if bis[-1] < num :
        bis.append(num)
      else :
        bis[bisect.bisect_left(bis, num)] = num
    DP[s] = len(bis)-1

  def LIS(s) :
    if s == -1: return DP[0] + 1
    return DP[s]
  # print([LIS(-1)] + DP)

  DP2 = [-1] * (N+1) #L[i]에서 시작하는 LIS의 갯수
  def count_lis(s): #S[s]에서 시작하는 LIS의 갯수를 반환한다.
    if LIS(s) == 1: return 1 #L[s]에서 시작하는 LIS가 1이면 자기 자신만 있다.
    ret = DP2[s+1]
    if ret != -1 : return ret

    ret = 0
    for nxt in range(s + 1, N) :
      if (s == -1 or L[s] < L[nxt]) and LIS(s) == (LIS(nxt) + 1) :
        ret = min(MAX, ret + count_lis(nxt))
    DP2[s+1] = ret
    return ret
  # print([count_lis(-1)] + [count_lis(i) for i in range(N)])

  def reconstruct(s, skip, lis: list) :
    if s != -1 : lis.append(L[s]) #S[s]는 길이가 1이므로 항상 LIS에 포함된다.
    followers = []
    for nxt in range(s + 1, N) :
      if (s == -1 or L[s] < L[nxt]) and LIS(s) == (LIS(nxt) + 1) :
        followers.append((L[nxt], nxt))
    followers.sort()

    for v, idx in followers :
      #이 숫자 뒤에 이어서 만들 수 있는 LIS의 갯수를 계산한다.
      cnt = count_lis(idx)
      if cnt <= skip :
        skip -= cnt
      else :
        reconstruct(idx, skip, lis)
        break

  x = []
  reconstruct(-1, K - 1, x)
  if x :
    print(" ".join(map(str, x)))
  else :
    print(-1)

sol()

# %%
import sys, io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

MAX = 2e9 + 7777
def sol() :
  N, K = map(int, input().split())
  L = [*map(int, input().split())]

  DP = [-1] * (N + 1) #L[i]에서 시작하는 LIS의 길이
  def LIS(s) : #L[s]에서 시작하는 IS중 최대 길이를 반환한다. O(N^2)
    ret = DP[s + 1]
    if ret != -1 : return ret #항상 S[s]는 있기 때문에 길이는 최소 1이다.

    ret = 1
    for i in range(s + 1, N) :
      if s == -1 or L[s] < L[i] :
        ret = max(ret, LIS(i) + 1)
    DP[s+1] = ret
    return ret

  DP2 = [-1] * (N+1) #L[i]에서 시작하는 LIS의 갯수
  def count_lis(s): #S[s]에서 시작하는 LIS의 갯수를 반환한다.
    if LIS(s) == 1: return 1 #L[s]에서 시작하는 LIS가 1이면 자기 자신만 있다.
    if DP2[s+1] != -1 : return DP2[s+1]

    ret = 0
    for nxt in range(s + 1, N) : #s보다 뒤에있는 인덱스 nxt 들을 순회하면서 nxt로부터 만들 수 있는 LIS의 개수를 재귀적으로 센다.
      if (s == -1 or L[s] < L[nxt]) and LIS(s) == LIS(nxt) + 1 :
        ret = min(MAX, ret + count_lis(nxt)) #2^250를 계산하게 될 수도 있으므로, 최대값을 지문에 적힌 MAX로 제한한다.
    DP2[s+1] = ret
    return ret
  #L[s]를 시작으로 하는 lis의 다음 s 다음의 index들의 집합을 S라고 할 때, L[s+1:] != S 이기 때문에 count_lis(0) 한번 만으로 모든 경우를 셀 수 없다.

  track = []
  def reconstruct(s, skip) : #재구성 O(N^2 log N)
    if s != -1 : #
      track.append(L[s]) 
    can = []
    for nxt in range(s + 1, N) :
      if (s == -1 or L[s] < L[nxt]) and LIS(s) == LIS(nxt) + 1 :
        can.append((L[nxt], nxt)) #현재까지 구성한 LIS 뒤에 올 수 있는 숫자들을 모두 찾는다. 사전순으로 찾아야 하므로 (v, i)를 저장한다.
    can.sort() #오름차순 정렬한다.

    for _, idx in can : 
      cnt = count_lis(idx) #각 후보들을 순회하면서 현재 숫자를 골랐을 때 만들 수 있는 LIS의 갯수를 센다.
      if cnt <= skip : #cnt가 더 크다면 만들어야 할 수열보다 앞에있는 것을 보고 있다는 뜻이므로, skip 만큼을 건너뛴다.
        skip -= cnt
      else : #cnt 범위 안에 정답이 있다는 의미이다. 나머지 수열을 재귀적으로 구성한다.
        reconstruct(idx, skip)
        break

  reconstruct(-1, K - 1)
  sys.stdout.write(" ".join(map(str, track)) + "\n" if track else "-1")

sol()

# %% [markdown]
# - 충격과 공포의 포인터 이슈. 참고를 위해 사용한 &int 의 존재를 간과하고 있었다. \
# 그 포인터에 있는 값을 수정하는 거였는데, Python코드로 옮겨적으면서 그부분을 간과했고, 계속 메모이제이션이 되지 않았다!

# %% [markdown]
# ### 풀이
# - 시간복잡도: $O(N^2 \log N)$
# - k번째 답 출력하기가 유형의 문제. 해당 테크닉의 레시피는 다음과 같다.
#   1. 정답을 사전순으로 만들며 경우의 수를 세는 완전탐색 알고리즘을 설계한다.
#   2. 메모이제이션을 적용해 중복되는 경우를 제거한 DP 알고리즘으로 바꾼다.
#   3. 모든 답들을 사전순으로 생성하여 $skip$ 개를 건너뛴 다음의 답을 출력하는 알고리즘을 만든다. \
#   이때, $M = \text{(현재 상태로부터 만들 수 있는 답의 수)}$ 을 $skip$ 과 비교하여 다음을 처리한다.
#       - $M \leq skip$: $M$ 개의 덥이 모두 원하는 답보다 앞에 있으므로(skip가능하므로) 이들을 건너뛴다. 그리고 $skip := skip - M$ 으로 갱신한다.
#       - $M > skip$: 원하는 답이 $M$ 개의 답 중에 있고, 현재 상태에서 $skip$ 번 건너뛴 것이 출력해야할 답이다.\
#       정답을 출력하고, 재귀함수로 나머지 부분을 출력한다.

# %% [markdown]
# - 레시피에 의하면, M을 구할 수 있어야 하는데, 이는 $L[i:]$ 에서 만들 수 있는 LIS의 개수라고 볼 수 있다.
#   - 우선 $L[i:]$ 에서 만들 수 있는 LIS의 길이를 구한다. 이를 $DP[i]$ 에 저장한다.
#     - $O(N \log N)$ LIS가 생각날 수 있지만, 전이할 때 구해둔 DP값을 이용할 수 없기 때문에 $O(N^2 \log N)$ 이 돼버릴 것이다.\
#     따라서 애초에 $L[i:]$ 에서 만드는 LIS의 길이를 구하는 $O(N^2)$ LIS 알고리즘이 최적임을 알 수 있다. 아마도.
#   - $i$ 번째 index에서 만들 수 있는 LIS의 개수를 구하는 함수를 $C(i)$ 라고 하자. $DP$ 를 이용하여 구할 수 있다.\
#   $i$ 를 시작으로 하는 lis에서 $i$ 다음에 올 수 있는 원소들의 후보 인덱스를 $j$ 라고하자.
#     - $i < j$: $i$ 보다 뒤에있는 원소를 보아야 하므로 당연하다.
#     - $L[i] < L[j]$: LIS의 정의에 의해 뒤에있는 원소의 값이 더 커야한다.
#     - $\displaystyle DP[i] = DP[j] + 1$: 핵심. $DP[j]$ 는 $DP[i]$ 보다 정확히 1 감소한 값이여야 한다.\
#     (증명) 아니라고 해보자. 즉, $DP[i] < DP[j] + 1$ 혹은 $DP[i] > DP[j] + 1$ 일때 lis를 구성할 수 있다고 가정하자.\
#     전자의 경우, 더 앞에있는 $DP[i]$ 를 포함해서 만든 lis보다 $DP[j]$ 를 포함하여 구성했을 때의 lis의 길이가 더 길다는 의미이다. \
#     애초에 $DP[j]$ 를 포함하면 $i$ 보다 더 뒤에있는 원소들을 가지고 lis를 만들 수 있었다는 의미이므로, 최적해가 아니게된다.\
#     후자의 경우, $DP[j]$ 가 아닌 원소를 포함했을 때 더 긴 lis를 만들 수 있다는 의미이다. 따라서 최적해가 아니다.
#     - 위 조건을 만족하는 $i$ 다음에 올 수 있는 $j$ 의 집합을 $\text{next}(i)$ 라고 해보자, $C(i)$ 는 다음과 같이 정의할 수 있다.\
#     $C(i) = \sum_{j \in \text{next}(i)} C(j)$
# - $M$ 를 구하는 함수를 만들었으니, 이제 $skip$ 과 비교하여 문제를 풀 수 있다. 재귀함수를 통해 구현할 수 있다
#   - 지금까지 구성한 LIS 이후에 올 숫자들의 후보들을 저장한다. 이때 후보들의 값과 인덱스를 같이 저장해야 수열을 사전순으로 정렬하면서 동시에 재구성도 할 수 있다.
#   - 구한 후보들을 값을 기준으로 정렬한다.
#   - 정렬된 후보들을 순회하며, $C(i)$ 를 구한다. \
#   이때, $skip \leq C(i)$ 일 경우, 사전순으로 $C(i)$ 만큼 앞에있는 수열들을 만들 수 있다는 뜻이므로 skip을 $C(i)$ 만큼 감소시킨다.\
#   그렇지 않은 경우, $C(i)$ 안에서 정답 수열을 만들 수 있다는 뜻이므로, 현재 구했던 인덱스를 이용해(`L[i]`) 후보를 출력하고 재귀함수를 호출한다.\
#   - 단, 초기 재귀함수 호출에서 $C(0) \leq skip$ 일 경우, 애초에 $L$ 로 부터 만들 수 있는 $k$ 보다 적다는 의미이므로, -1을 출력한다.

# %% [markdown]
# ### $O(N^2)$ 풀이
# - 수열을 재구성할때마다 후보들을 정렬하면서 각 step에서 $\log N$ 만큼의 연산이 추가로 적용되고 있다.\
# 만약 이 부분을 개선할 수 있다면 $O(N^2)$ 로 만들 수 있을 것이다.
#   - 어떤 숫자를 2개의 기준으로 정렬하되, 매번 사전순으로 찾을 수 있도록 설계할 수 있다. \
#   L을 (v, i)순으로 정렬하되, 수열을 재귀적으로 찾기 위해 다시 살펴볼땐 skip을 할 수 있도록 하는 구조체를 설계한다.

# %%
import sys, io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

from dataclasses import dataclass
@dataclass
class candidate :
  idx : int #원본 수열에서의 위치
  value : int 
  skip: bool #출력할 수열의 위치가 확정됐을 때, 그 위치보다 왼쪽에 있는 원소들을 다시 살펴보면 안된다. 이를 스킵하기 위한 flag

MAX = 2e9 + 7777
def sol() :
  N, K = map(int, input().split())
  L = [*map(int, input().split())]
  CAN = [candidate(i, v, False) for i, v in enumerate(L)]
  CAN.sort(key=lambda x : x.value) #값 기준으로 오름차순 정렬

  DP = [-1] * (N + 1) #L[i]에서 시작하는 LIS의 길이
  def LIS(s) : #L[s]에서 시작하는 IS중 최대 길이를 반환한다. O(N^2)
    ret = DP[s + 1]
    if ret != -1 : return ret #항상 S[s]는 있기 때문에 길이는 최소 1이다.

    ret = 1
    for i in range(s + 1, N) :
      if s == -1 or L[s] < L[i] :
        ret = max(ret, LIS(i) + 1)
    DP[s+1] = ret
    return ret

  DP2 = [-1] * (N+1) #L[i]에서 시작하는 LIS의 갯수
  def count_lis(s): #S[s]에서 시작하는 LIS의 갯수를 반환한다.
    if LIS(s) == 1: return 1 #L[s]에서 시작하는 LIS가 1이면 자기 자신만 있다.
    if DP2[s+1] != -1 : return DP2[s+1]

    ret = 0
    for nxt in range(s + 1, N) : #s보다 뒤에있는 인덱스 nxt 들을 순회하면서 nxt로부터 만들 수 있는 LIS의 개수를 재귀적으로 센다.
      if (s == -1 or L[s] < L[nxt]) and LIS(s) == LIS(nxt) + 1 :
        ret = min(MAX, ret + count_lis(nxt)) #2^250 개의 숫자를 계산하게 될 수도 있으므로, 최대값을 지문에 적힌 MAX로 제한한다.
    DP2[s+1] = ret
    return ret
  #L[s]를 시작으로 하는 lis의 다음 s 다음의 index들의 집합을 S라고 할 때, L[s+1:] != S 이기 때문에 count_lis(0) 한번 만으로 모든 경우를 셀 수 없다.

  track = []
  def recon(s, K) : #재구성 O(N^2)
    if s != -1 : track.append(L[s]) 
    for can in CAN :
      if can.skip : continue
      if (s == -1 or L[s] < can.value) and LIS(s) == LIS(can.idx) + 1 :
        cnt = count_lis(can.idx)
        if cnt <= K :
          K -= cnt
        else :
          for can2 in CAN : #위치를 확정한 원소보다 왼쪽에 있는 원소들은 스킵한다.
            if can2.idx > can.idx : continue
            can2.skip = True
          return recon(can.idx, K)


  recon(-1, K - 1)
  sys.stdout.write(" ".join(map(str, track)) + "\n" if track else "-1")

sol()

# %% [markdown]
# - $O(N^2)$ 인것 같다고 생각한 코드인데, 메모리 사용량이 오히려 늘어나고, 속도는 느려졌다(344ms -> 416ms) \
# 구조체가 문제인지 아니면 skip을 처리하는데에 $O(N)$ 작업이 문제인지 살펴봐야겠다.

# %%
import sys, io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline
MAX = 2e9 + 7777
def sol() :
  N, K = map(int, input().split())
  L = [*map(int, input().split())]
  CAN = [[i, v, False] for i, v in enumerate(L)]
  CAN.sort(key=lambda x : x[1])

  DP = [-1] * (N + 1) #L[i]에서 시작하는 LIS의 길이
  def LIS(s) : #L[s]에서 시작하는 IS중 최대 길이를 반환한다. O(N^2)
    ret = DP[s + 1]
    if ret != -1 : return ret #항상 S[s]는 있기 때문에 길이는 최소 1이다.

    ret = 1
    for i in range(s + 1, N) :
      if s == -1 or L[s] < L[i] :
        ret = max(ret, LIS(i) + 1)
    DP[s+1] = ret
    return ret

  DP2 = [-1] * (N+1) #L[i]에서 시작하는 LIS의 갯수
  def count_lis(s): #S[s]에서 시작하는 LIS의 갯수를 반환한다.
    if LIS(s) == 1: return 1 #L[s]에서 시작하는 LIS가 1이면 자기 자신만 있다.
    if DP2[s+1] != -1 : return DP2[s+1]

    ret = 0
    for nxt in range(s + 1, N) : #s보다 뒤에있는 인덱스 nxt 들을 순회하면서 nxt로부터 만들 수 있는 LIS의 개수를 재귀적으로 센다.
      if (s == -1 or L[s] < L[nxt]) and LIS(s) == LIS(nxt) + 1 :
        ret = min(MAX, ret + count_lis(nxt)) #2^250 개의 숫자를 계산하게 될 수도 있으므로, 최대값을 지문에 적힌 MAX로 제한한다.
    DP2[s+1] = ret
    return ret
  #L[s]를 시작으로 하는 lis의 다음 s 다음의 index들의 집합을 S라고 할 때, L[s+1:] != S 이기 때문에 count_lis(0) 한번 만으로 모든 경우를 셀 수 없다.

  track = []
  def recon(s, K) : #재구성 O(N^2)
    if s != -1 : track.append(L[s]) 
    for can in CAN :
      if can[2] : continue
      if (s == -1 or L[s] < can[1]) and LIS(s) == LIS(can[0]) + 1 :
        cnt = count_lis(can[0])
        if cnt <= K :
          K -= cnt
        else :
          for can2 in CAN : #위치를 확정한 원소보다 왼쪽에 있는 원소들은 스킵한다.
            if can2[0] > can[0] : continue
            can2[2] = True
          return recon(can[0], K)

  recon(-1, K - 1)
  sys.stdout.write(" ".join(map(str, track)) + "\n" if track else "-1")

sol()

# %% [markdown]
# - dataclass가 추가적인 메모리를 사용하는 것이 큰 문제였던 것 같다. 그냥 list로 다뤄주니 속도 향상이 있었다.(412ms -> 252ms)
# - 다만 아직 내가 원하는 속도까지 나오지 않았다. iterative 최적화를 건드리기 전에 더 건드릴 곳은 없는지 관찰해본다.

# %% [markdown]
# 8 6
# 5 1 6 4 3 2 8 7
# ;;
# 500 100
# 2 1 4 3 6 5 8 7 10 9 12 11 14 13 16 15 18 17 20 19 22 21 24 23 26 25 28 27 30 29 32 31 34 33 36 35 38 37 40 39 42 41 44 43 46 45 48 47 50 49 52 51 54 53 56 55 58 57 60 59 62 61 64 63 66 65 68 67 70 69 72 71 74 73 76 75 78 77 80 79 82 81 84 83 86 85 88 87 90 89 92 91 94 93 96 95 98 97 100 99 102 101 104 103 106 105 108 107 110 109 112 111 114 113 116 115 118 117 120 119 122 121 124 123 126 125 128 127 130 129 132 131 134 133 136 135 138 137 140 139 142 141 144 143 146 145 148 147 150 149 152 151 154 153 156 155 158 157 160 159 162 161 164 163 166 165 168 167 170 169 172 171 174 173 176 175 178 177 180 179 182 181 184 183 186 185 188 187 190 189 192 191 194 193 196 195 198 197 200 199 202 201 204 203 206 205 208 207 210 209 212 211 214 213 216 215 218 217 220 219 222 221 224 223 226 225 228 227 230 229 232 231 234 233 236 235 238 237 240 239 242 241 244 243 246 245 248 247 250 249 252 251 254 253 256 255 258 257 260 259 262 261 264 263 266 265 268 267 270 269 272 271 274 273 276 275 278 277 280 279 282 281 284 283 286 285 288 287 290 289 292 291 294 293 296 295 298 297 300 299 302 301 304 303 306 305 308 307 310 309 312 311 314 313 316 315 318 317 320 319 322 321 324 323 326 325 328 327 330 329 332 331 334 333 336 335 338 337 340 339 342 341 344 343 346 345 348 347 350 349 352 351 354 353 356 355 358 357 360 359 362 361 364 363 366 365 368 367 370 369 372 371 374 373 376 375 378 377 380 379 382 381 384 383 386 385 388 387 390 389 392 391 394 393 396 395 398 397 400 399 402 401 404 403 406 405 408 407 410 409 412 411 414 413 416 415 418 417 420 419 422 421 424 423 426 425 428 427 430 429 432 431 434 433 436 435 438 437 440 439 442 441 444 443 446 445 448 447 450 449 452 451 454 453 456 455 458 457 460 459 462 461 464 463 466 465 468 467 470 469 472 471 474 473 476 475 478 477 480 479 482 481 484 483 486 485 488 487 490 489 492 491 494 493 496 495 498 497 500 499

# %%
import sys
input = sys.stdin.readline
N,M = map(int,input().split())
L = list(map(int, input().split()))
L = [int(-1e9)]+L+[int(1e9)]
dp = [1]*(N+2)
dp2 = [-1]*(N+2)
s = []
s.append((L[0],0))
for i in range(1,N+2):
  for j in range(i):
    if L[j] < L[i] and dp[i] < dp[j]+1:
      dp[i] = dp[j]+1
  s.append((L[i], i))
s.sort()
K = max(dp)
ans = []
dp[-1] = K

def rec(s):
  if s == N: return 1
  if dp2[s] != -1: return dp2[s]
  dp2[s] = 0
  for nxt in range(s+1,N+1):
    if L[s] < L[nxt] and dp[s]+1==dp[nxt]:
      dp2[s] = min(1e9,dp2[s]+rec(nxt))
  return dp2[s]

def f(p, K, s: list[tuple[int, int]]):
  if p == N: return 1
  if p:
    ans.append(L[p])
  new = s.copy()
  for x,y in new:
    if L[p] < L[y] and dp[p]+1 == dp[y]: #다음 LIS로 올 수 있으면
      if K < rec(y): #만들 수 있는 숫자를 세고, skip보다 작다면, (즉 현재 step에서 출력할 숫자를 y로 확정했다는 뜻)
        for i,j in new:
          if j <= y: #위치가 확정된 y보다 더 작은 인덱스를 모두 제거
            s.remove((i,j))
        return f(y,K,s.copy()) #나머지 숫자들을 재귀적으로 구성한다.
      K -= rec(y) #y를 확정하기 이전의 skip은 M보다 크므로 skip -= M을 해준다.
  return 0
N += 1
f(0,M-1,s)
if ans:
  print(*ans)
else:
  print(-1)

# %%
import sys, io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline
MAX = 2e9 + 7777
def sol() :
  N, K = map(int, input().split())
  L = [-MAX] + [*map(int, input().split())] + [MAX]
  CAN = []

  DP = [1] * (N+2) #L[:i]에서 LIS의 길이
  for i, l in enumerate(L[1:], 1) :
    for j in range(i) :
      if L[j] < l :
        DP[i] = max(DP[i], DP[j] + 1)
    CAN.append((i, l))
  CAN.sort(key=lambda x : x[1])
  DP[-1] = max(DP)
  LIS = lambda s: DP[s]

  DP2 = [-1] * (N+2)
  def count_lis(s):
    if s == N : return 1
    if DP2[s] != -1 : return DP2[s]

    ret = 0
    for nxt in range(s+1, N+1) :
      if (s == -1 or L[s] < L[nxt]) and LIS(s)+1 == LIS(nxt) :
        ret = min(MAX, ret + count_lis(nxt))
    DP2[s] = ret
    return ret

  track = []
  def recon(s, K) : #재구성 O(N^2)
    if s == N: return 1
    if s: track.append(L[s]) 
    for i, v in CAN :
      if s < i and L[s] < v and LIS(s) + 1 == LIS(i) :
        cnt = count_lis(i)
        if cnt <= K :
          K -= cnt
        else :
          return recon(i, K)
  N += 1
  recon(0, K - 1)
  sys.stdout.write(" ".join(map(str, track)) + "\n" if track else "-1")

sol()

# %% [markdown]
# - 재귀문을 한개 없애니 속도가 비약적으로 상승했다. 나머지 재귀문도 iterative하게 풀 수 있다면 더 빨라질 수도 있을 것 같다. (252ms -> 88ms)
# - 추가로, recon에서 별도의 자료구조 구현없이 현재 확정된 인덱스보다 초과된 것만 보면 된다는 사실을 발견했다. \
# 그 부분을 지웠더니 속도가 추가로 향상됐다.(88ms -> 84ms) 위의 코드는 84ms짜리 코드

# %%
import sys, io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline
MAX = 2e9 + 7777
def sol() :
  N, K = map(int, input().split())
  L = [-MAX] + [*map(int, input().split())] + [MAX]
  CAN = []

  DP = [1] * (N+2) #L[:i]에서 LIS의 길이
  for i, l in enumerate(L[1:], 1) :
    for j in range(i) :
      if L[j] < l :
        DP[i] = max(DP[i], DP[j] + 1)
    CAN.append((i, l))
  CAN.sort(key=lambda x : x[1])
  DP[-1] = max(DP)
  LIS = lambda s: DP[s]

  DP2 = [-1] * (N+2)
  DP2[-1] = 1 #기저상태
  for s in reversed(range(N+1)) :
    ret = 0
    for nxt in range(s+1, N+2) :
      if L[s] < L[nxt] and LIS(s) + 1 == LIS(nxt) :
        ret = min(MAX, ret + DP2[nxt])
    DP2[s] = ret

  def count_lis(s):
    if s == N : return 1
    if DP2[s] != -1 : return DP2[s]

  track = []
  N += 1
  K = K - 1
  S = [0]
  while S:  #iterative 재구성
    s = S.pop()
    if s == N: continue
    if s: track.append(L[s])
    for i, v in CAN :
      if s < i and L[s] < v and LIS(s) + 1 == LIS(i) :
        cnt = count_lis(i)
        if cnt <= K :
          K -= cnt
        else :
          S.append(i)
          break
  sys.stdout.write(" ".join(map(str, track)) + "\n" if track else "-1")

sol()

# %% [markdown]
# - DP2는, 뒤에 있는 LIS의 길이만 본다는 점에서 관찰했고, loop를 거꾸로 돌려서 구현했다.
#   - 재귀에서 비재귀로 바꿀 때, 재귀 호출문이 for문 안에 있다면 변환이 매우 어려워서 다른 접근 한 결과가 이것이다.
# - 반면 recon은 index를 확정했을 때에만 재귀문이 깊어지므로 쉽게 최적화할 수 있었다.
# - 아쉽게도 속도 향상은 없었다. 메모리 사용량만 44KB 정도 감소했다.
