# %%
import io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

def bipartite(G, N, M) :
  def dfs(x) :
    if vis[x]: return False

    vis[x] = True
    for y in G[x]:
      if sel[y] == -1 :
        sel[y] = x
        return True
      
    for y in G[x] :
      if dfs(sel[y]):
        sel[y] = x
        return True
    return False

  sel = [-1] * max(N, M)
  res = 0
  for i in range(N) :
    vis = [False] * N
    res += dfs(i)
  return res, sel

def sol() :
  C, D, E = map(int, input().split())
  G = [set() for _ in range(C)]
  for _ in range(E) :
    u, v = sorted(input().split())
    u, v = int(u[1:])-1, int(v[1:])-1
    G[u].add(v)
  
  res, sel = bipartite(G, C, D)
  return E-res

ans = []
for _ in range(int(input())) :
  ans.append(sol())

print(*ans, sep='\n')

# %% [markdown]
# - $i \to j$랑 $j \to i$ 랑 똑같은거 아닌가?

# %%
import io, os
input=io.BytesIO(os.read(0,os.fstat(0).st_size)).readline

def bipartite(G, N, M) :
  def dfs(x) :
    if vis[x]: return False

    vis[x] = True
    for y in G[x]:
      if sel[y] == -1 :
        sel[y] = x
        return True
      
    for y in G[x] :
      if dfs(sel[y]):
        sel[y] = x
        return True
    return False

  sel = [-1] * max(N, M)
  res = 0
  for i in range(N) :
    vis = [False] * N
    res += dfs(i)
  return res, sel

def sol() :
  C, D, E = map(int, input().split())
  G = [[] for _ in range(501)]
  V = []
  for i in range(E) :
    u, v = input().split()
    V.append((u, v))

  for i in range(E-1) :
    for j in range(i+1, E) :
      if V[i][0] == V[j][1] or V[j][0] == V[i][1] :
        if V[i][0][0] == 67: G[i].append(j)
        else : G[j].append(i)
  
  res, sel = bipartite(G, 501, 501)
  return E-res

ans = []
for _ in range(int(input())) :
  ans.append(sol())

print(*ans, sep='\n')
